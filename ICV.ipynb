# %% [markdown]
# <a href="https://colab.research.google.com/github/maryofcarmo/ICV/blob/main/ICV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ligar ao Google e chamar bibliotecas necessárias

# %%
# conecta o notebook ao google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# inicia chamando todas as bibliotecas necessárias
import pandas as pd
import os
import numpy as np
import geopandas as gpd
import matplotlib.pyplot as plt
from shapely.geometry import Point

# %% [markdown]
# # Leitura dos arquivos e colocar todos em um dicionário

# %%
# Defina o diretório onde estão os arquivos CSV
diretorio = '/content/drive/MyDrive/TCC/DADOS/SERIES_TEMP_LIMPAS'

# Obtenha a lista de todos os arquivos CSV no diretório
arquivos_csv = [f for f in os.listdir(diretorio) if f.endswith('.csv')]

arquivos_csv
# Out:
# ['Nome:_AGUA_BRANCA_Codigo_Estacao:_82989.csv',
#  'Nome:_ARAPIRACA_Codigo_Estacao:_82995.csv',
#  'Nome:_MACEIO_Codigo_Estacao:_82994.csv',
#  'Nome:_MAJOR_ISIDORO_Codigo_Estacao:_82991.csv',
#  'Nome:_MATA_GRANDE_Codigo_Estacao:_82988.csv',
#  'Nome:_PALMEIRA_DOS_INDIOS_Codigo_Estacao:_82992.csv',
#  'Nome:_PAO_DE_ACUCAR_Codigo_Estacao:_82990.csv',
#  'Nome:_PILAR_(MANGUABA)_Codigo_Estacao:_82998.csv',
#  'Nome:_PORTO_DE_PEDRAS_Codigo_Estacao:_82996.csv',
#  'Nome:_ALAGOINHAS_Codigo_Estacao:_83249.csv',
#  'Nome:_BARRA_Codigo_Estacao:_83179.csv',
#  'Nome:_CAETITE_Codigo_Estacao:_83339.csv',
#  'Nome:_CAMACARI_Codigo_Estacao:_83226.csv',
#  'Nome:_CANAVIEIRAS_Codigo_Estacao:_83398.csv',
#  'Nome:_CARINHANHA_Codigo_Estacao:_83408.csv',
#  'Nome:_CIPO_Codigo_Estacao:_83192.csv',
#  'Nome:_CORRENTINA_Codigo_Estacao:_83286.csv',
#  'Nome:_CRUZ_DAS_ALMAS_Codigo_Estacao:_83222.csv',
#  'Nome:_FEIRA_DE_SANTANA_Codigo_Estacao:_83221.csv',
#  'Nome:_GUARATINGA_Codigo_Estacao:_83446.csv',
#  'Nome:_IRECE_Codigo_Estacao:_83182.csv',
#  'Nome:_ITABERABA_Codigo_Estacao:_83244.csv',
#  'Nome:_ITABUNA_Codigo_Estacao:_83347.csv',
#  'Nome:_ITIRUCU_(JAGUAQUARA)_Codigo_Estacao:_83295.csv',
#  'Nome:_ITUACU_Codigo_Estacao:_83292.csv',
#  'Nome:_MONTE_SANTO_Codigo_Estacao:_83090.csv',
#  'Nome:_MORRO_DO_CHAPEU_Codigo_Estacao:_83184.csv',
#  'Nome:_MUCURI_Codigo_Estacao:_83549.csv',
#  'Nome:_PAULO_AFONSO_Codigo_Estacao:_82986.csv',
#  'Nome:_REMANSO_Codigo_Estacao:_82979.csv',
#  'Nome:_SENHOR_DO_BONFIM_Codigo_Estacao:_83088.csv',
#  'Nome:_SERRINHA_Codigo_Estacao:_83190.csv',
#  'Nome:_STa._R._DE_CASSIA_(IBIPETUBA)_Codigo_Estacao:_83076.csv',
#  'Nome:_ACARAU_Codigo_Estacao:_82294.csv',
#  'Nome:_CAMPOS_SALES_Codigo_Estacao:_82777.csv',
#  'Nome:_GUARAMIRANGA_Codigo_Estacao:_82487.csv',
#  'Nome:_IGUATU_Codigo_Estacao:_82686.csv',
#  'Nome:_JAGUARUANA_Codigo_Estacao:_82493.csv',
#  'Nome:_JUAZEIRO_DO_NORTE_Codigo_Estacao:_82785.csv',
#  'Nome:_MORADA_NOVA_Codigo_Estacao:_82588.csv',
#  'Nome:_QUIXADA_Codigo_Estacao:_82486.csv',
#  'Nome:_SOBRAL_Codigo_Estacao:_82392.csv',
#  'Nome:_TAUA_Codigo_Estacao:_82683.csv',
#  'Nome:_VICOSA_DO_CEARA_Codigo_Estacao:_82390.csv',
#  'Nome:_ALTO_PARNAIBA_Codigo_Estacao:_82970.csv',
#  'Nome:_BALSAS_Codigo_Estacao:_82768.csv',
#  'Nome:_CAXIAS_Codigo_Estacao:_82476.csv',
#  'Nome:_CHAPADINHA_Codigo_Estacao:_82382.csv',
#  'Nome:_COLINAS_Codigo_Estacao:_82676.csv',
#  'Nome:_IMPERATRIZ_Codigo_Estacao:_82564.csv',
#  'Nome:_TURIACU_Codigo_Estacao:_82198.csv',
#  'Nome:_ZE_DOCA_Codigo_Estacao:_82376.csv',
#  'Nome:_AREIA_Codigo_Estacao:_82696.csv',
#  'Nome:_CAMARATUBA_Codigo_Estacao:_82695.csv',
#  'Nome:_CAMPINA_GRANDE_Codigo_Estacao:_82795.csv',
#  'Nome:_GUARABIRA_Codigo_Estacao:_82697.csv',
#  'Nome:_JOAO_PESSOA_Codigo_Estacao:_82798.csv',
#  'Nome:_MONTEIRO_Codigo_Estacao:_82792.csv',
#  'Nome:_SAO_GONCALO_Codigo_Estacao:_82689.csv',
#  'Nome:_ARCO_VERDE_Codigo_Estacao:_82890.csv',
#  'Nome:_CABROBO_Codigo_Estacao:_82886.csv',
#  'Nome:_GARANHUNS_Codigo_Estacao:_82893.csv',
#  'Nome:_GOIANA_Codigo_Estacao:_82799.csv',
#  'Nome:_NAZARE_DA_MATA_Codigo_Estacao:_82781.csv',
#  'Nome:_OLINDA_Codigo_Estacao:_82898.csv',
#  'Nome:_OURICURI_Codigo_Estacao:_82753.csv',
#  'Nome:_PESQUEIRA_Codigo_Estacao:_82892.csv',
#  'Nome:_SURUBIM_Codigo_Estacao:_82797.csv',
#  'Nome:_TAPACURA_Codigo_Estacao:_82897.csv',
#  'Nome:_TRIUNFO_Codigo_Estacao:_82789.csv',
#  'Nome:_ALTO_LONGA_(PILOTO_DO_LONGA)_Codigo_Estacao:_82605.csv',
#  'Nome:_BOM_JESUS_DO_PIAUI_Codigo_Estacao:_82975.csv',
#  'Nome:_CALDEIRAO_Codigo_Estacao:_82474.csv',
#  'Nome:_CARACOL_Codigo_Estacao:_82976.csv',
#  'Nome:_ESPERANTINA_Codigo_Estacao:_82298.csv',
#  'Nome:_LUZILANDIA(LAG.DO_PIAUI)_Codigo_Estacao:_82296.csv',
#  'Nome:_MORRO_DOS_CAVALOS_Codigo_Estacao:_82684.csv',
#  'Nome:_PAULISTANA_Codigo_Estacao:_82882.csv',
#  'Nome:_PICOS_Codigo_Estacao:_82780.csv',
#  'Nome:_PIRIPIRI_Codigo_Estacao:_82480.csv',
#  'Nome:_SAO_JOAO_DO_PIAUI_Codigo_Estacao:_82879.csv',
#  'Nome:_VALE_DO_GURGUEIA_(CRISTIANO_CASTRO)_Codigo_Estacao:_82870.csv',
#  'Nome:_APODI_Codigo_Estacao:_82590.csv',
#  'Nome:_CEARA_MIRIM_Codigo_Estacao:_82596.csv',
#  'Nome:_CRUZETA_Codigo_Estacao:_82693.csv',
#  'Nome:_FLORANIA_Codigo_Estacao:_82691.csv',
#  'Nome:_MACAIBA_Codigo_Estacao:_82597.csv',
#  'Nome:_MACAU_Codigo_Estacao:_82594.csv',
#  'Nome:_MOSSORO_Codigo_Estacao:_82591.csv',
#  'Nome:_NOVA_CRUZ_Codigo_Estacao:_82698.csv',
#  'Nome:_SERIDO_(CAICO)_Codigo_Estacao:_82690.csv',
#  'Nome:_ITABAIANINHA_Codigo_Estacao:_83195.csv',
#  'Nome:_PROPRIA_Codigo_Estacao:_83097.csv',
#  'Nome:_BARREIRAS_Codigo_Estacao:_83236.csv',
#  'Nome:_BOM_JESUS_DA_LAPA_Codigo_Estacao:_83288.csv',
#  'Nome:_CARAVELAS_Codigo_Estacao:_83498.csv',
#  'Nome:_JACOBINA_Codigo_Estacao:_83186.csv',
#  'Nome:_LENCOIS_Codigo_Estacao:_83242.csv',
#  'Nome:_SALVADOR_(ONDINA)_Codigo_Estacao:_83229.csv',
#  'Nome:_VITORIA_DA_CONQUISTA_Codigo_Estacao:_83344.csv',
#  'Nome:_BARBALHA_Codigo_Estacao:_82784.csv',
#  'Nome:_CRATEUS_Codigo_Estacao:_82583.csv',
#  'Nome:_FORTALEZA_Codigo_Estacao:_82397.csv',
#  'Nome:_QUIXERAMOBIM_Codigo_Estacao:_82586.csv',
#  'Nome:_BACABAL_Codigo_Estacao:_82460.csv',
#  'Nome:_BARRA_DO_CORDA_Codigo_Estacao:_82571.csv',
#  'Nome:_CAROLINA_Codigo_Estacao:_82765.csv',
#  'Nome:_SAO_LUIS_Codigo_Estacao:_82280.csv',
#  'Nome:_PATOS_Codigo_Estacao:_82791.csv',
#  'Nome:_PETROLINA_Codigo_Estacao:_82983.csv',
#  'Nome:_RECIFE_(CURADO)_Codigo_Estacao:_82900.csv',
#  'Nome:_FLORIANO_Codigo_Estacao:_82678.csv',
#  'Nome:_PARNAIBA_Codigo_Estacao:_82287.csv',
#  'Nome:_TERESINA_Codigo_Estacao:_82578.csv',
#  'Nome:_NATAL_Codigo_Estacao:_82598.csv',
#  'Nome:_ARACAJU_Codigo_Estacao:_83096.csv']

# %% [markdown]
# Armazeno os 116 arquivos em um dicionário denominado 'series_temp'
# - seto a primeira coluna de cada dataframe como index
# - transformo o index no tipo datatime

# %%
# dicionário para armazenar as séries temporais
series_temp = {}


# Loop para ler cada arquivo CSV e armazenar no dicionário
for arquivo in arquivos_csv:

    caminho_completo = os.path.join(diretorio, arquivo)

    #obtem o nome do arquivo sem a sua extensão e coloca na variável 'nome_df'
    nome_df = os.path.splitext(arquivo)[0]

    # Lê o arquivo CSV e armazena no dicionário com o nome do arquivo como chave
    series_temp[nome_df] = pd.read_csv(caminho_completo)

    # Setar a primeira coluna, sem dizer o nome da coluna, como o índice
    series_temp[nome_df].set_index(series_temp[nome_df].columns[0], inplace=True)

    # Converter o índice para datetime
    series_temp[nome_df].index = pd.to_datetime(series_temp[nome_df].index)

# %%
#verificando uma série aleatoria
ex1 = series_temp['Nome:_AGUA_BRANCA_Codigo_Estacao:_82989']
ex1
# Out:
#             PRECIPITACAO TOTAL, MENSAL(mm)  INSOLACAO TOTAL, MENSAL(h)  \
# Unnamed: 0
# 2000-01-31                           941.8                         5.5
# 2000-02-29                           943.4                         5.8
# 2000-03-31                           942.3                         6.3
# 2000-04-30                           943.5                         6.9
# 2000-05-31                           945.0                         6.4
# ...                                    ...                         ...
# 2023-05-31                           946.9                         7.6
# 2023-06-30                           948.7                         8.5
# 2023-07-31                           949.1                         8.2
# 2023-10-31                           946.3                         2.2
# 2023-11-30                           945.0                         2.1
#
#             VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# Unnamed: 0
# 2000-01-31                                 70.0
# 2000-02-29                                 69.0
# 2000-03-31                                 70.0
# 2000-04-30                                 69.2
# 2000-05-31                                 63.7
# ...                                         ...
# 2023-05-31                                 97.5
# 2023-06-30                                 96.9
# 2023-07-31                                 97.1
# 2023-10-31                                 98.0
# 2023-11-30                                 98.0
#
# [259 rows x 3 columns]

# %%
# verifico cada tipo de variável
ex1.dtypes
# Out:
# PRECIPITACAO TOTAL, MENSAL(mm)         float64
# INSOLACAO TOTAL, MENSAL(h)             float64
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)    float64
# dtype: object

# %%
# verifico o tipo do index também
type(ex1.index)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %%
#verificando uma segunda série aleatoria
ex2 = series_temp['Nome:_BARREIRAS_Codigo_Estacao:_83236']
ex2.head()
# Out:
#               PRECIPITACAO TOTAL, MENSAL(mm)  INSOLACAO TOTAL, MENSAL(h)  \
# Data Medicao
# 2000-06-30                               0.1                       287.4
# 2000-07-31                               0.2                       286.2
# 2000-08-31                               0.6                        10.4
# 2000-09-30                              39.1                       241.4
# 2000-10-31                              12.7                       254.4
#
#               VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# Data Medicao
# 2000-06-30                                    1.2
# 2000-07-31                                    1.3
# 2000-08-31                                    1.6
# 2000-09-30                                    2.0
# 2000-10-31                                    1.8

# %%
# verifico cada tipo de variável
ex2.dtypes
# Out:
# PRECIPITACAO TOTAL, MENSAL(mm)         float64
# INSOLACAO TOTAL, MENSAL(h)             float64
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)    float64
# dtype: object

# %%
# verifico o tipo do index também
type(ex2.index)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %% [markdown]
# # Verificar quais as séries temporais estão vazias

# %%
# Inicializar uma lista para armazenar os nomes das séries que estão vazias
series_vazias = []

# Iterar sobre cada série no dicionário 'series_temp'
for nome, df in series_temp.items():
    # Verificar se o DataFrame está vazio
    if df.empty:
        # Se estiver vazio, adicionar o nome da série à lista
        series_vazias.append(nome)

# Exibir a lista de séries vazias
for series in series_vazias:
    print(series)
# Out:
# Nome:_ARAPIRACA_Codigo_Estacao:_82995
# Nome:_MAJOR_ISIDORO_Codigo_Estacao:_82991
# Nome:_MATA_GRANDE_Codigo_Estacao:_82988
# Nome:_PILAR_(MANGUABA)_Codigo_Estacao:_82998
# Nome:_ITABUNA_Codigo_Estacao:_83347
# Nome:_MUCURI_Codigo_Estacao:_83549
# Nome:_JUAZEIRO_DO_NORTE_Codigo_Estacao:_82785
# Nome:_QUIXADA_Codigo_Estacao:_82486
# Nome:_VICOSA_DO_CEARA_Codigo_Estacao:_82390
# Nome:_GUARABIRA_Codigo_Estacao:_82697
# Nome:_GOIANA_Codigo_Estacao:_82799
# Nome:_NAZARE_DA_MATA_Codigo_Estacao:_82781
# Nome:_OLINDA_Codigo_Estacao:_82898
# Nome:_PESQUEIRA_Codigo_Estacao:_82892
# Nome:_TAPACURA_Codigo_Estacao:_82897
# Nome:_ALTO_LONGA_(PILOTO_DO_LONGA)_Codigo_Estacao:_82605
# Nome:_CALDEIRAO_Codigo_Estacao:_82474
# Nome:_ESPERANTINA_Codigo_Estacao:_82298
# Nome:_LUZILANDIA(LAG.DO_PIAUI)_Codigo_Estacao:_82296
# Nome:_MORRO_DOS_CAVALOS_Codigo_Estacao:_82684
# Nome:_VALE_DO_GURGUEIA_(CRISTIANO_CASTRO)_Codigo_Estacao:_82870
# Nome:_MACAIBA_Codigo_Estacao:_82597
# Nome:_NOVA_CRUZ_Codigo_Estacao:_82698

# %%
#verifico a quantidade de séries vazias
len(series_vazias)
# Out:
# 23

# %% [markdown]
# # Construção do Ano Característico

# %%
#crio um dicionário para armazenar o ano característico de cada série
ano_caracteristico = {}

#loop que fará todo o trabalho de percorrer o dicionário de séries temporais
for nome_serie, serie in series_temp.items(): # chave:nome_serie, valor:serie

  #pega cada série limpa individualmente e joga na variável df
  #df = series_temp[nome_serie]

  # agrupa esse df por cada mês e faz a média
  df_ano_caracteristico = series_temp[nome_serie].groupby(series_temp[nome_serie].index.month).mean()

  # joga esse agrupamento por mês de cada série no dicionário criado para o ano característico
  ano_caracteristico[nome_serie] = df_ano_caracteristico

# %%
#escolhendo uma estação para verificar se deu certo
ano_caracteristico['Nome:_PALMEIRA_DOS_INDIOS_Codigo_Estacao:_82992']
# Out:
#             PRECIPITACAO TOTAL, MENSAL(mm)  INSOLACAO TOTAL, MENSAL(h)  \
# Unnamed: 0
# 1                               981.324000                    6.156000
# 2                               981.160000                    6.460000
# 3                               981.152000                    6.412000
# 4                               981.596000                    6.636000
# 5                               983.004000                    7.424000
# 6                               984.966667                    7.633333
# 7                               985.883333                    7.575000
# 8                               986.012500                    7.304167
# 9                               985.165217                    6.560870
# 10                              983.125000                    5.975000
# 11                              981.204167                    5.629167
# 12                              981.113636                    5.840909
#
#             VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# Unnamed: 0
# 1                                     65.912000
# 2                                     65.796000
# 3                                     65.812000
# 4                                     65.584000
# 5                                     65.672000
# 6                                     64.333333
# 7                                     65.345833
# 8                                     65.891667
# 9                                     65.008696
# 10                                    66.787500
# 11                                    67.108333
# 12                                    65.745455

# %%
#verificando mais uma estação para ver se deu certo
ano_caracteristico['Nome:_BARREIRAS_Codigo_Estacao:_83236']
# Out:
#               PRECIPITACAO TOTAL, MENSAL(mm)  INSOLACAO TOTAL, MENSAL(h)  \
# Data Medicao
# 1                                 197.200000                  212.257895
# 2                                 134.784211                  191.373684
# 3                                 134.222222                  217.855556
# 4                                  77.829412                  233.905882
# 5                                  14.358824                  266.335294
# 6                                   3.752941                  282.623529
# 7                                   0.815789                  298.763158
# 8                                   0.685000                  277.300000
# 9                                  14.961905                  264.519048
# 10                                 55.926316                  254.473684
# 11                                171.652632                  182.694737
# 12                                207.325000                  203.668750
#
#               VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# Data Medicao
# 1                                        1.147368
# 2                                        1.121053
# 3                                        0.966667
# 4                                        0.976471
# 5                                        1.052941
# 6                                        1.194118
# 7                                        1.378947
# 8                                        1.570000
# 9                                        1.919048
# 10                                       1.852632
# 11                                       1.426316
# 12                                       1.243750

# %% [markdown]
# # Coeficientes de Correlação

# %% [markdown]
# ## Corelação de Pearson

# %%
# Dicionário para armazenar as MATRIZES de correlação de Pearson
pearson_results = {}

# Loop para iterar sobre cada DataFrame no dicionário
for nome_serie, serie in ano_caracteristico.items():
    # Calculando o coeficiente de Pearson entre cada par de colunas
    pearson_matrix = serie.corr(method='pearson')

    # Armazenar os resultados no dicionário
    pearson_results[nome_serie] = pearson_matrix

# %%
# Exibir os resultados
for nome_serie, pearson_matrix in pearson_results.items():
    print(f"Coeficientes de Pearson para o DataFrame {nome_serie}:")
    print(pearson_matrix)
    print()
# Out:
# Coeficientes de Pearson para o DataFrame Nome:_AGUA_BRANCA_Codigo_Estacao:_82989:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                 0.789641
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.771172
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                         0.789641
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.952617
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.771172
# INSOLACAO TOTAL, MENSAL(h)                                     -0.952617
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Pearson para o DataFrame Nome:_ARAPIRACA_Codigo_Estacao:_82995:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                                  NaN
# INSOLACAO TOTAL, MENSAL(h)                                      NaN
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             NaN
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                              NaN
# INSOLACAO TOTAL, MENSAL(h)                                  NaN
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                         NaN
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                       NaN
# INSOLACAO TOTAL, MENSAL(h)                                           NaN
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                                  NaN
#
# Coeficientes de Pearson para o DataFrame Nome:_MACEIO_Codigo_Estacao:_82994:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                 0.668656
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.659552
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                         0.668656
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.492009
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.659552
# INSOLACAO TOTAL, MENSAL(h)                                     -0.492009
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Pearson para o DataFrame Nome:_MAJOR_ISIDORO_Codigo_Estacao:_82991:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                                  NaN
# INSOLACAO TOTAL, MENSAL(h)                                      NaN
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             NaN
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                              NaN
# INSOLACAO TOTAL, MENSAL(h)                                  NaN
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                         NaN
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                       NaN
# INSOLACAO TOTAL, MENSAL(h)                                           NaN
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                                  NaN
#
# Coeficientes de Pearson para o DataFrame Nome:_MATA_GRANDE_Codigo_Estacao:_82988:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                                  NaN
# INSOLACAO TOTAL, MENSAL(h)                                      NaN
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             NaN
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                              NaN
# INSOLACAO TOTAL, MENSAL(h)                                  NaN
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                         NaN
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                       NaN
# INSOLACAO TOTAL, MENSAL(h)                                           NaN
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                                  NaN
#
# Coeficientes de Pearson para o DataFrame Nome:_PALMEIRA_DOS_INDIOS_Codigo_Estacao:_82992:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                 0.733587
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.481364
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                         0.733587
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.696482
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.481364
# INSOLACAO TOTAL, MENSAL(h)                                     -0.696482
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Pearson para o DataFrame Nome:_PAO_DE_ACUCAR_Codigo_Estacao:_82990:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                 0.630290
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.705835
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                         0.630290
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.940163
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.705835
# INSOLACAO TOTAL, MENSAL(h)                                     -0.940163
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Pearson para o DataFrame Nome:_PILAR_(MANGUABA)_Codigo_Estacao:_82998:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                                  NaN
# INSOLACAO TOTAL, MENSAL(h)                                      NaN
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             NaN
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                              NaN
# INSOLACAO TOTAL, MENSAL(h)                                  NaN
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                         NaN
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                       NaN
# INSOLACAO TOTAL, MENSAL(h)                                           NaN
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                                  NaN
#
# Coeficientes de Pearson para o DataFrame Nome:_PORTO_DE_PEDRAS_Codigo_Estacao:_82996:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                 0.477049
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.713409
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                         0.477049
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.833801
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.713409
# INSOLACAO TOTAL, MENSAL(h)                                     -0.833801
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Pearson para o DataFrame Nome:_ALAGOINHAS_Codigo_Estacao:_83249:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                 0.727185
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.281771
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                         0.727185
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.009774
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.281771
# INSOLACAO TOTAL, MENSAL(h)                                     -0.009774
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Pearson para o DataFrame Nome:_BARRA_Codigo_Estacao:_83179:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.896825
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.395667
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.896825
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                    0.230164
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.395667
# INSOLACAO TOTAL, MENSAL(h)                                      0.230164
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Pearson para o DataFrame Nome:_CAETITE_Codigo_Estacao:_83339:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.822427
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                        0.222134
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.822427
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.707864
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                  0.222134
# INSOLACAO TOTAL, MENSAL(h)                                     -0.707864
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Pearson para o DataFrame Nome:_CAMACARI_Codigo_Estacao:_83226:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                 0.664823
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.834846
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                         0.664823
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.879398
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.834846
# INSOLACAO TOTAL, MENSAL(h)                                     -0.879398
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Pearson para o DataFrame Nome:_CANAVIEIRAS_Codigo_Estacao:_83398:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                 0.518194
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.073933
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                         0.518194
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                    0.071738
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.073933
# INSOLACAO TOTAL, MENSAL(h)                                      0.071738
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Pearson para o DataFrame Nome:_CARINHANHA_Codigo_Estacao:_83408:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.944030
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.125326
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.944030
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.159413
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.125326
# INSOLACAO TOTAL, MENSAL(h)                                     -0.159413
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Pearson para o DataFrame Nome:_CIPO_Codigo_Estacao:_83192:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                 0.613490
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.563462
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                         0.613490
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.160206
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.563462
# INSOLACAO TOTAL, MENSAL(h)                                     -0.160206
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Pearson para o DataFrame Nome:_CORRENTINA_Codigo_Estacao:_83286:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.928108
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                        0.439278
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.928108
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.258477
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                  0.439278
# INSOLACAO TOTAL, MENSAL(h)                                     -0.258477
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Pearson para o DataFrame Nome:_CRUZ_DAS_ALMAS_Codigo_Estacao:_83222:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                 0.709479
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.840677
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                         0.709479
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.716667
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.840677
# INSOLACAO TOTAL, MENSAL(h)                                     -0.716667
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Pearson para o DataFrame Nome:_FEIRA_DE_SANTANA_Codigo_Estacao:_83221:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                 0.737647
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.625459
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                         0.737647
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.874387
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.625459
# INSOLACAO TOTAL, MENSAL(h)                                     -0.874387
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Pearson para o DataFrame Nome:_GUARATINGA_Codigo_Estacao:_83446:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.516878
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.431034
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.516878
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.365583
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.431034
# INSOLACAO TOTAL, MENSAL(h)                                     -0.365583
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Pearson para o DataFrame Nome:_IRECE_Codigo_Estacao:_83182:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.912672
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                        0.079674
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.912672
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                    0.103840
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                  0.079674
# INSOLACAO TOTAL, MENSAL(h)                                      0.103840
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Pearson para o DataFrame Nome:_ITABERABA_Codigo_Estacao:_83244:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                 0.293772
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.475367
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                         0.293772
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.288341
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.475367
# INSOLACAO TOTAL, MENSAL(h)                                     -0.288341
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Pearson para o DataFrame Nome:_ITABUNA_Codigo_Estacao:_83347:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                                  NaN
# INSOLACAO TOTAL, MENSAL(h)                                      NaN
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             NaN
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                              NaN
# INSOLACAO TOTAL, MENSAL(h)                                  NaN
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                         NaN
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                       NaN
# INSOLACAO TOTAL, MENSAL(h)                                           NaN
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                                  NaN
#
# Coeficientes de Pearson para o DataFrame Nome:_ITIRUCU_(JAGUAQUARA)_Codigo_Estacao:_83295:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                 0.031538
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.743737
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                         0.031538
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.415313
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.743737
# INSOLACAO TOTAL, MENSAL(h)                                     -0.415313
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Pearson para o DataFrame Nome:_ITUACU_Codigo_Estacao:_83292:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.607989
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                        0.756280
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.607989
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.302222
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                  0.756280
# INSOLACAO TOTAL, MENSAL(h)                                     -0.302222
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Pearson para o DataFrame Nome:_MONTE_SANTO_Codigo_Estacao:_83090:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                 0.551707
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.831693
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                         0.551707
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.842568
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.831693
# INSOLACAO TOTAL, MENSAL(h)                                     -0.842568
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Pearson para o DataFrame Nome:_MORRO_DO_CHAPEU_Codigo_Estacao:_83184:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                 0.276257
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.601511
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                         0.276257
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.850493
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.601511
# INSOLACAO TOTAL, MENSAL(h)                                     -0.850493
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Pearson para o DataFrame Nome:_MUCURI_Codigo_Estacao:_83549:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                                  NaN
# INSOLACAO TOTAL, MENSAL(h)                                      NaN
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             NaN
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                              NaN
# INSOLACAO TOTAL, MENSAL(h)                                  NaN
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                         NaN
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                       NaN
# INSOLACAO TOTAL, MENSAL(h)                                           NaN
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                                  NaN
#
# Coeficientes de Pearson para o DataFrame Nome:_PAULO_AFONSO_Codigo_Estacao:_82986:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                 0.552183
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.847032
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                         0.552183
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.855743
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.847032
# INSOLACAO TOTAL, MENSAL(h)                                     -0.855743
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Pearson para o DataFrame Nome:_REMANSO_Codigo_Estacao:_82979:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.795647
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                        0.457967
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.795647
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.112455
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                  0.457967
# INSOLACAO TOTAL, MENSAL(h)                                     -0.112455
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Pearson para o DataFrame Nome:_SENHOR_DO_BONFIM_Codigo_Estacao:_83088:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                 0.656221
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.879052
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                         0.656221
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.852624
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.879052
# INSOLACAO TOTAL, MENSAL(h)                                     -0.852624
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Pearson para o DataFrame Nome:_SERRINHA_Codigo_Estacao:_83190:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                 0.531922
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.806141
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                         0.531922
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.899631
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.806141
# INSOLACAO TOTAL, MENSAL(h)                                     -0.899631
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Pearson para o DataFrame Nome:_STa._R._DE_CASSIA_(IBIPETUBA)_Codigo_Estacao:_83076:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.906367
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.080562
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.906367
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.190598
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.080562
# INSOLACAO TOTAL, MENSAL(h)                                     -0.190598
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Pearson para o DataFrame Nome:_ACARAU_Codigo_Estacao:_82294:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.721575
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.191032
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.721575
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                    0.007680
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.191032
# INSOLACAO TOTAL, MENSAL(h)                                      0.007680
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Pearson para o DataFrame Nome:_CAMPOS_SALES_Codigo_Estacao:_82777:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.781588
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.457964
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.781588
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                    0.757218
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.457964
# INSOLACAO TOTAL, MENSAL(h)                                      0.757218
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Pearson para o DataFrame Nome:_GUARAMIRANGA_Codigo_Estacao:_82487:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.389953
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.336662
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.389953
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.544149
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.336662
# INSOLACAO TOTAL, MENSAL(h)                                     -0.544149
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Pearson para o DataFrame Nome:_IGUATU_Codigo_Estacao:_82686:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.448309
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.490704
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.448309
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                    0.300190
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.490704
# INSOLACAO TOTAL, MENSAL(h)                                      0.300190
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Pearson para o DataFrame Nome:_JAGUARUANA_Codigo_Estacao:_82493:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.561966
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.012697
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.561966
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.390943
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.012697
# INSOLACAO TOTAL, MENSAL(h)                                     -0.390943
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Pearson para o DataFrame Nome:_JUAZEIRO_DO_NORTE_Codigo_Estacao:_82785:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                                  NaN
# INSOLACAO TOTAL, MENSAL(h)                                      NaN
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             NaN
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                              NaN
# INSOLACAO TOTAL, MENSAL(h)                                  NaN
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                         NaN
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                       NaN
# INSOLACAO TOTAL, MENSAL(h)                                           NaN
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                                  NaN
#
# Coeficientes de Pearson para o DataFrame Nome:_MORADA_NOVA_Codigo_Estacao:_82588:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.560806
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                        0.403217
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.560806
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.542838
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                  0.403217
# INSOLACAO TOTAL, MENSAL(h)                                     -0.542838
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Pearson para o DataFrame Nome:_QUIXADA_Codigo_Estacao:_82486:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                                  NaN
# INSOLACAO TOTAL, MENSAL(h)                                      NaN
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             NaN
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                              NaN
# INSOLACAO TOTAL, MENSAL(h)                                  NaN
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                         NaN
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                       NaN
# INSOLACAO TOTAL, MENSAL(h)                                           NaN
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                                  NaN
#
# Coeficientes de Pearson para o DataFrame Nome:_SOBRAL_Codigo_Estacao:_82392:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.409747
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.490925
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.409747
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                    0.196881
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.490925
# INSOLACAO TOTAL, MENSAL(h)                                      0.196881
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Pearson para o DataFrame Nome:_TAUA_Codigo_Estacao:_82683:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.561453
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                        0.690494
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.561453
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.464715
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                  0.690494
# INSOLACAO TOTAL, MENSAL(h)                                     -0.464715
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Pearson para o DataFrame Nome:_VICOSA_DO_CEARA_Codigo_Estacao:_82390:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                                  NaN
# INSOLACAO TOTAL, MENSAL(h)                                      NaN
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             NaN
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                              NaN
# INSOLACAO TOTAL, MENSAL(h)                                  NaN
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                         NaN
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                       NaN
# INSOLACAO TOTAL, MENSAL(h)                                           NaN
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                                  NaN
#
# Coeficientes de Pearson para o DataFrame Nome:_ALTO_PARNAIBA_Codigo_Estacao:_82970:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.932022
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                        0.856360
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.932022
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.832606
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                  0.856360
# INSOLACAO TOTAL, MENSAL(h)                                     -0.832606
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Pearson para o DataFrame Nome:_BALSAS_Codigo_Estacao:_82768:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.840120
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                        0.094705
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.840120
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.117996
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                  0.094705
# INSOLACAO TOTAL, MENSAL(h)                                     -0.117996
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Pearson para o DataFrame Nome:_CAXIAS_Codigo_Estacao:_82476:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.551093
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                        0.041335
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.551093
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                    0.520561
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                  0.041335
# INSOLACAO TOTAL, MENSAL(h)                                      0.520561
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Pearson para o DataFrame Nome:_CHAPADINHA_Codigo_Estacao:_82382:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.363115
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                        0.015597
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.363115
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.727721
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                  0.015597
# INSOLACAO TOTAL, MENSAL(h)                                     -0.727721
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Pearson para o DataFrame Nome:_COLINAS_Codigo_Estacao:_82676:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.696853
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                        0.695838
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.696853
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.512013
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                  0.695838
# INSOLACAO TOTAL, MENSAL(h)                                     -0.512013
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Pearson para o DataFrame Nome:_IMPERATRIZ_Codigo_Estacao:_82564:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.865087
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                        0.771737
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.865087
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.802169
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                  0.771737
# INSOLACAO TOTAL, MENSAL(h)                                     -0.802169
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Pearson para o DataFrame Nome:_TURIACU_Codigo_Estacao:_82198:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.386010
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                        0.092499
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.386010
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                    0.530314
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                  0.092499
# INSOLACAO TOTAL, MENSAL(h)                                      0.530314
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Pearson para o DataFrame Nome:_ZE_DOCA_Codigo_Estacao:_82376:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# ...
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Pearson para o DataFrame Nome:_VITORIA_DA_CONQUISTA_Codigo_Estacao:_83344:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                 0.017951
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.365879
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                         0.017951
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                    0.488994
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.365879
# INSOLACAO TOTAL, MENSAL(h)                                      0.488994
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Pearson para o DataFrame Nome:_BARBALHA_Codigo_Estacao:_82784:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.801521
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.894852
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.801521
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                    0.728031
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.894852
# INSOLACAO TOTAL, MENSAL(h)                                      0.728031
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Pearson para o DataFrame Nome:_CRATEUS_Codigo_Estacao:_82583:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.871598
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.889928
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.871598
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                    0.900299
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.889928
# INSOLACAO TOTAL, MENSAL(h)                                      0.900299
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Pearson para o DataFrame Nome:_FORTALEZA_Codigo_Estacao:_82397:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.962113
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.950396
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.962113
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                    0.968900
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.950396
# INSOLACAO TOTAL, MENSAL(h)                                      0.968900
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Pearson para o DataFrame Nome:_QUIXERAMOBIM_Codigo_Estacao:_82586:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.917283
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.784451
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.917283
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                    0.738168
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.784451
# INSOLACAO TOTAL, MENSAL(h)                                      0.738168
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Pearson para o DataFrame Nome:_BACABAL_Codigo_Estacao:_82460:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.899764
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.682139
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.899764
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                    0.474204
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.682139
# INSOLACAO TOTAL, MENSAL(h)                                      0.474204
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Pearson para o DataFrame Nome:_BARRA_DO_CORDA_Codigo_Estacao:_82571:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.917354
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.909028
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.917354
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                    0.813172
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.909028
# INSOLACAO TOTAL, MENSAL(h)                                      0.813172
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Pearson para o DataFrame Nome:_CAROLINA_Codigo_Estacao:_82765:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.928258
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.831891
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.928258
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                    0.793031
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.831891
# INSOLACAO TOTAL, MENSAL(h)                                      0.793031
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Pearson para o DataFrame Nome:_SAO_LUIS_Codigo_Estacao:_82280:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.966953
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.841134
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.966953
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                    0.749152
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.841134
# INSOLACAO TOTAL, MENSAL(h)                                      0.749152
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Pearson para o DataFrame Nome:_PATOS_Codigo_Estacao:_82791:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.461928
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.784455
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.461928
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                    0.799088
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.784455
# INSOLACAO TOTAL, MENSAL(h)                                      0.799088
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Pearson para o DataFrame Nome:_PETROLINA_Codigo_Estacao:_82983:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.472147
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.917428
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.472147
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                    0.575151
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.917428
# INSOLACAO TOTAL, MENSAL(h)                                      0.575151
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Pearson para o DataFrame Nome:_RECIFE_(CURADO)_Codigo_Estacao:_82900:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.886522
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.931470
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.886522
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                    0.744669
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.931470
# INSOLACAO TOTAL, MENSAL(h)                                      0.744669
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Pearson para o DataFrame Nome:_FLORIANO_Codigo_Estacao:_82678:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.951673
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.912411
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.951673
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                    0.938733
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.912411
# INSOLACAO TOTAL, MENSAL(h)                                      0.938733
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Pearson para o DataFrame Nome:_PARNAIBA_Codigo_Estacao:_82287:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.943692
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.642575
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.943692
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                    0.595619
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.642575
# INSOLACAO TOTAL, MENSAL(h)                                      0.595619
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Pearson para o DataFrame Nome:_TERESINA_Codigo_Estacao:_82578:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.916741
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.854452
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.916741
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                    0.836257
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.854452
# INSOLACAO TOTAL, MENSAL(h)                                      0.836257
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Pearson para o DataFrame Nome:_NATAL_Codigo_Estacao:_82598:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.928561
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.778336
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.928561
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                    0.797946
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.778336
# INSOLACAO TOTAL, MENSAL(h)                                      0.797946
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Pearson para o DataFrame Nome:_ARACAJU_Codigo_Estacao:_83096:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.884286
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.910234
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.884286
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                    0.948704
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.910234
# INSOLACAO TOTAL, MENSAL(h)                                      0.948704
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000

# %%
# Exemplo de como acessar uma das matrizes de correlação de person resultante
pearson_results['Nome:_ITABAIANINHA_Codigo_Estacao:_83195']
# Out:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                 0.731130
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.612028
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                         0.731130
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.885413
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.612028
# INSOLACAO TOTAL, MENSAL(h)                                     -0.885413
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000

# %% [markdown]
# ## Correlação de Kendall

# %%
# Dicionário para armazenar os coeficientes de Kendall
kendall_results = {}

# Loop para iterar sobre cada DataFrame no dicionário
for nome_serie, serie in ano_caracteristico.items():
    # Calculando o coeficiente de Pearson entre cada par de colunas
    kendall_matrix = serie.corr(method='kendall')

    # Armazenar os resultados no dicionário
    kendall_results[nome_serie] = kendall_matrix

# %%
# Exibir os resultados
for nome_serie, kendall_matrix in kendall_results.items():
    print(f"Coeficientes de Kendall para a Série {nome_serie}:")
    print(kendall_matrix)
    print()
# Out:
# Coeficientes de Kendall para a Série Nome:_AGUA_BRANCA_Codigo_Estacao:_82989:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                 0.606061
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.515152
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                         0.606061
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.848485
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.515152
# INSOLACAO TOTAL, MENSAL(h)                                     -0.848485
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Kendall para a Série Nome:_ARAPIRACA_Codigo_Estacao:_82995:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                                  NaN
# INSOLACAO TOTAL, MENSAL(h)                                      NaN
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             NaN
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                              NaN
# INSOLACAO TOTAL, MENSAL(h)                                  NaN
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                         NaN
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                       NaN
# INSOLACAO TOTAL, MENSAL(h)                                           NaN
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                                  NaN
#
# Coeficientes de Kendall para a Série Nome:_MACEIO_Codigo_Estacao:_82994:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                 0.381691
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.584615
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                         0.381691
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.442761
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.584615
# INSOLACAO TOTAL, MENSAL(h)                                     -0.442761
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Kendall para a Série Nome:_MAJOR_ISIDORO_Codigo_Estacao:_82991:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                                  NaN
# INSOLACAO TOTAL, MENSAL(h)                                      NaN
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             NaN
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                              NaN
# INSOLACAO TOTAL, MENSAL(h)                                  NaN
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                         NaN
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                       NaN
# INSOLACAO TOTAL, MENSAL(h)                                           NaN
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                                  NaN
#
# Coeficientes de Kendall para a Série Nome:_MATA_GRANDE_Codigo_Estacao:_82988:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                                  NaN
# INSOLACAO TOTAL, MENSAL(h)                                      NaN
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             NaN
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                              NaN
# INSOLACAO TOTAL, MENSAL(h)                                  NaN
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                         NaN
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                       NaN
# INSOLACAO TOTAL, MENSAL(h)                                           NaN
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                                  NaN
#
# Coeficientes de Kendall para a Série Nome:_PALMEIRA_DOS_INDIOS_Codigo_Estacao:_82992:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                 0.484848
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.212121
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                         0.484848
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.606061
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.212121
# INSOLACAO TOTAL, MENSAL(h)                                     -0.606061
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Kendall para a Série Nome:_PAO_DE_ACUCAR_Codigo_Estacao:_82990:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                 0.454545
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.636364
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                         0.454545
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.818182
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.636364
# INSOLACAO TOTAL, MENSAL(h)                                     -0.818182
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Kendall para a Série Nome:_PILAR_(MANGUABA)_Codigo_Estacao:_82998:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                                  NaN
# INSOLACAO TOTAL, MENSAL(h)                                      NaN
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             NaN
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                              NaN
# INSOLACAO TOTAL, MENSAL(h)                                  NaN
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                         NaN
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                       NaN
# INSOLACAO TOTAL, MENSAL(h)                                           NaN
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                                  NaN
#
# Coeficientes de Kendall para a Série Nome:_PORTO_DE_PEDRAS_Codigo_Estacao:_82996:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                 0.181818
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.515152
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                         0.181818
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.545455
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.515152
# INSOLACAO TOTAL, MENSAL(h)                                     -0.545455
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Kendall para a Série Nome:_ALAGOINHAS_Codigo_Estacao:_83249:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                 0.454545
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.272727
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                         0.454545
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.151515
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.272727
# INSOLACAO TOTAL, MENSAL(h)                                     -0.151515
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Kendall para a Série Nome:_BARRA_Codigo_Estacao:_83179:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.575758
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                        0.030303
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.575758
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                    0.030303
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                  0.030303
# INSOLACAO TOTAL, MENSAL(h)                                      0.030303
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Kendall para a Série Nome:_CAETITE_Codigo_Estacao:_83339:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.696970
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                        0.212121
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.696970
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.515152
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                  0.212121
# INSOLACAO TOTAL, MENSAL(h)                                     -0.515152
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Kendall para a Série Nome:_CAMACARI_Codigo_Estacao:_83226:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                 0.545455
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.545455
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                         0.545455
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.757576
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.545455
# INSOLACAO TOTAL, MENSAL(h)                                     -0.757576
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Kendall para a Série Nome:_CANAVIEIRAS_Codigo_Estacao:_83398:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                 0.424242
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.151515
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                         0.424242
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                    0.000000
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.151515
# INSOLACAO TOTAL, MENSAL(h)                                      0.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Kendall para a Série Nome:_CARINHANHA_Codigo_Estacao:_83408:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.878788
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                        0.060606
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.878788
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.121212
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                  0.060606
# INSOLACAO TOTAL, MENSAL(h)                                     -0.121212
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Kendall para a Série Nome:_CIPO_Codigo_Estacao:_83192:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                 0.303030
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.424242
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                         0.303030
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                    0.030303
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.424242
# INSOLACAO TOTAL, MENSAL(h)                                      0.030303
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Kendall para a Série Nome:_CORRENTINA_Codigo_Estacao:_83286:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.787879
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                        0.259550
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.787879
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.106873
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                  0.259550
# INSOLACAO TOTAL, MENSAL(h)                                     -0.106873
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Kendall para a Série Nome:_CRUZ_DAS_ALMAS_Codigo_Estacao:_83222:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                 0.393939
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.696970
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                         0.393939
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.515152
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.696970
# INSOLACAO TOTAL, MENSAL(h)                                     -0.515152
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Kendall para a Série Nome:_FEIRA_DE_SANTANA_Codigo_Estacao:_83221:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                 0.666667
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.393939
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                         0.666667
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.606061
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.393939
# INSOLACAO TOTAL, MENSAL(h)                                     -0.606061
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Kendall para a Série Nome:_GUARATINGA_Codigo_Estacao:_83446:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.484848
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.290085
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.484848
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.137409
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.290085
# INSOLACAO TOTAL, MENSAL(h)                                     -0.137409
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Kendall para a Série Nome:_IRECE_Codigo_Estacao:_83182:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.666667
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.030303
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.666667
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                    0.363636
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.030303
# INSOLACAO TOTAL, MENSAL(h)                                      0.363636
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Kendall para a Série Nome:_ITABERABA_Codigo_Estacao:_83244:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                 0.272727
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.272727
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                         0.272727
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.212121
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.272727
# INSOLACAO TOTAL, MENSAL(h)                                     -0.212121
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Kendall para a Série Nome:_ITABUNA_Codigo_Estacao:_83347:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                                  NaN
# INSOLACAO TOTAL, MENSAL(h)                                      NaN
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             NaN
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                              NaN
# INSOLACAO TOTAL, MENSAL(h)                                  NaN
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                         NaN
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                       NaN
# INSOLACAO TOTAL, MENSAL(h)                                           NaN
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                                  NaN
#
# Coeficientes de Kendall para a Série Nome:_ITIRUCU_(JAGUAQUARA)_Codigo_Estacao:_83295:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                 0.121212
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.696970
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                         0.121212
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.242424
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.696970
# INSOLACAO TOTAL, MENSAL(h)                                     -0.242424
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Kendall para a Série Nome:_ITUACU_Codigo_Estacao:_83292:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.473296
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                        0.787879
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.473296
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.381691
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                  0.787879
# INSOLACAO TOTAL, MENSAL(h)                                     -0.381691
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Kendall para a Série Nome:_MONTE_SANTO_Codigo_Estacao:_83090:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                 0.473296
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.606061
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                         0.473296
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.748113
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.606061
# INSOLACAO TOTAL, MENSAL(h)                                     -0.748113
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Kendall para a Série Nome:_MORRO_DO_CHAPEU_Codigo_Estacao:_83184:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                 0.363636
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.484848
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                         0.363636
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.757576
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.484848
# INSOLACAO TOTAL, MENSAL(h)                                     -0.757576
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Kendall para a Série Nome:_MUCURI_Codigo_Estacao:_83549:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                                  NaN
# INSOLACAO TOTAL, MENSAL(h)                                      NaN
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             NaN
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                              NaN
# INSOLACAO TOTAL, MENSAL(h)                                  NaN
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                         NaN
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                       NaN
# INSOLACAO TOTAL, MENSAL(h)                                           NaN
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                                  NaN
#
# Coeficientes de Kendall para a Série Nome:_PAULO_AFONSO_Codigo_Estacao:_82986:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                 0.484848
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.636364
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                         0.484848
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.606061
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.636364
# INSOLACAO TOTAL, MENSAL(h)                                     -0.606061
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Kendall para a Série Nome:_REMANSO_Codigo_Estacao:_82979:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.515152
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                        0.424242
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.515152
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.242424
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                  0.424242
# INSOLACAO TOTAL, MENSAL(h)                                     -0.242424
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Kendall para a Série Nome:_SENHOR_DO_BONFIM_Codigo_Estacao:_83088:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                 0.545455
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.696970
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                         0.545455
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.727273
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.696970
# INSOLACAO TOTAL, MENSAL(h)                                     -0.727273
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Kendall para a Série Nome:_SERRINHA_Codigo_Estacao:_83190:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                 0.484848
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.606061
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                         0.484848
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.696970
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.606061
# INSOLACAO TOTAL, MENSAL(h)                                     -0.696970
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Kendall para a Série Nome:_STa._R._DE_CASSIA_(IBIPETUBA)_Codigo_Estacao:_83076:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.575758
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.090909
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.575758
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.212121
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.090909
# INSOLACAO TOTAL, MENSAL(h)                                     -0.212121
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Kendall para a Série Nome:_ACARAU_Codigo_Estacao:_82294:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.454545
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                        0.030303
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.454545
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                    0.030303
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                  0.030303
# INSOLACAO TOTAL, MENSAL(h)                                      0.030303
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Kendall para a Série Nome:_CAMPOS_SALES_Codigo_Estacao:_82777:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.515152
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.212121
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.515152
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                    0.454545
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.212121
# INSOLACAO TOTAL, MENSAL(h)                                      0.454545
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Kendall para a Série Nome:_GUARAMIRANGA_Codigo_Estacao:_82487:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.303030
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.151515
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.303030
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.545455
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.151515
# INSOLACAO TOTAL, MENSAL(h)                                     -0.545455
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Kendall para a Série Nome:_IGUATU_Codigo_Estacao:_82686:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.303030
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                        0.090909
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.303030
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                    0.181818
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                  0.090909
# INSOLACAO TOTAL, MENSAL(h)                                      0.181818
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Kendall para a Série Nome:_JAGUARUANA_Codigo_Estacao:_82493:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.424242
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                        0.000000
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.424242
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.333333
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                  0.000000
# INSOLACAO TOTAL, MENSAL(h)                                     -0.333333
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Kendall para a Série Nome:_JUAZEIRO_DO_NORTE_Codigo_Estacao:_82785:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                                  NaN
# INSOLACAO TOTAL, MENSAL(h)                                      NaN
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             NaN
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                              NaN
# INSOLACAO TOTAL, MENSAL(h)                                  NaN
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                         NaN
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                       NaN
# INSOLACAO TOTAL, MENSAL(h)                                           NaN
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                                  NaN
#
# Coeficientes de Kendall para a Série Nome:_MORADA_NOVA_Codigo_Estacao:_82588:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.333333
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                        0.060606
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.333333
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.363636
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                  0.060606
# INSOLACAO TOTAL, MENSAL(h)                                     -0.363636
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Kendall para a Série Nome:_QUIXADA_Codigo_Estacao:_82486:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                                  NaN
# INSOLACAO TOTAL, MENSAL(h)                                      NaN
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             NaN
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                              NaN
# INSOLACAO TOTAL, MENSAL(h)                                  NaN
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                         NaN
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                       NaN
# INSOLACAO TOTAL, MENSAL(h)                                           NaN
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                                  NaN
#
# Coeficientes de Kendall para a Série Nome:_SOBRAL_Codigo_Estacao:_82392:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.242424
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.303030
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.242424
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.212121
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.303030
# INSOLACAO TOTAL, MENSAL(h)                                     -0.212121
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Kendall para a Série Nome:_TAUA_Codigo_Estacao:_82683:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.363636
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                        0.575758
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.363636
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.363636
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                  0.575758
# INSOLACAO TOTAL, MENSAL(h)                                     -0.363636
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Kendall para a Série Nome:_VICOSA_DO_CEARA_Codigo_Estacao:_82390:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                                  NaN
# INSOLACAO TOTAL, MENSAL(h)                                      NaN
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             NaN
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                              NaN
# INSOLACAO TOTAL, MENSAL(h)                                  NaN
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                         NaN
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                       NaN
# INSOLACAO TOTAL, MENSAL(h)                                           NaN
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                                  NaN
#
# Coeficientes de Kendall para a Série Nome:_ALTO_PARNAIBA_Codigo_Estacao:_82970:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.636364
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                        0.575758
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.636364
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.757576
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                  0.575758
# INSOLACAO TOTAL, MENSAL(h)                                     -0.757576
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Kendall para a Série Nome:_BALSAS_Codigo_Estacao:_82768:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.515152
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                        0.000000
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.515152
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.121212
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                  0.000000
# INSOLACAO TOTAL, MENSAL(h)                                     -0.121212
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Kendall para a Série Nome:_CAXIAS_Codigo_Estacao:_82476:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.333333
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                        0.000000
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.333333
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                    0.363636
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                  0.000000
# INSOLACAO TOTAL, MENSAL(h)                                      0.363636
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Kendall para a Série Nome:_CHAPADINHA_Codigo_Estacao:_82382:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.151515
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.121212
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.151515
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.606061
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.121212
# INSOLACAO TOTAL, MENSAL(h)                                     -0.606061
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Kendall para a Série Nome:_COLINAS_Codigo_Estacao:_82676:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.393939
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                        0.575758
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.393939
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.272727
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                  0.575758
# INSOLACAO TOTAL, MENSAL(h)                                     -0.272727
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Kendall para a Série Nome:_IMPERATRIZ_Codigo_Estacao:_82564:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.515152
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                        0.636364
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.515152
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.575758
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                  0.636364
# INSOLACAO TOTAL, MENSAL(h)                                     -0.575758
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Kendall para a Série Nome:_TURIACU_Codigo_Estacao:_82198:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.151515
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                        0.121212
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.151515
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                    0.242424
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                  0.121212
# INSOLACAO TOTAL, MENSAL(h)                                      0.242424
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Kendall para a Série Nome:_ZE_DOCA_Codigo_Estacao:_82376:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.242424
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.121212
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# ...
# INSOLACAO TOTAL, MENSAL(h)                                     -0.151515
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Kendall para a Série Nome:_VITORIA_DA_CONQUISTA_Codigo_Estacao:_83344:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.060606
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.212121
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.060606
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                    0.242424
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.212121
# INSOLACAO TOTAL, MENSAL(h)                                      0.242424
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Kendall para a Série Nome:_BARBALHA_Codigo_Estacao:_82784:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.727273
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.878788
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.727273
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                    0.606061
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.878788
# INSOLACAO TOTAL, MENSAL(h)                                      0.606061
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Kendall para a Série Nome:_CRATEUS_Codigo_Estacao:_82583:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.757576
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.818182
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.757576
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                    0.757576
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.818182
# INSOLACAO TOTAL, MENSAL(h)                                      0.757576
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Kendall para a Série Nome:_FORTALEZA_Codigo_Estacao:_82397:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.878788
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.939394
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.878788
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                    0.878788
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.939394
# INSOLACAO TOTAL, MENSAL(h)                                      0.878788
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Kendall para a Série Nome:_QUIXERAMOBIM_Codigo_Estacao:_82586:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.818182
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.606061
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.818182
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                    0.484848
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.606061
# INSOLACAO TOTAL, MENSAL(h)                                      0.484848
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Kendall para a Série Nome:_BACABAL_Codigo_Estacao:_82460:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.727273
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.636364
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.727273
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                    0.424242
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.636364
# INSOLACAO TOTAL, MENSAL(h)                                      0.424242
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Kendall para a Série Nome:_BARRA_DO_CORDA_Codigo_Estacao:_82571:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.878788
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.839719
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.878788
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                    0.717578
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.839719
# INSOLACAO TOTAL, MENSAL(h)                                      0.717578
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Kendall para a Série Nome:_CAROLINA_Codigo_Estacao:_82765:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.787879
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.545455
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.787879
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                    0.515152
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.545455
# INSOLACAO TOTAL, MENSAL(h)                                      0.515152
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Kendall para a Série Nome:_SAO_LUIS_Codigo_Estacao:_82280:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.818182
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.666667
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.818182
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                    0.545455
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.666667
# INSOLACAO TOTAL, MENSAL(h)                                      0.545455
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Kendall para a Série Nome:_PATOS_Codigo_Estacao:_82791:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.424242
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.727273
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.424242
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                    0.575758
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.727273
# INSOLACAO TOTAL, MENSAL(h)                                      0.575758
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Kendall para a Série Nome:_PETROLINA_Codigo_Estacao:_82983:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.333333
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.848485
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.333333
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                    0.424242
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.848485
# INSOLACAO TOTAL, MENSAL(h)                                      0.424242
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Kendall para a Série Nome:_RECIFE_(CURADO)_Codigo_Estacao:_82900:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.787879
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.848485
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.787879
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                    0.636364
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.848485
# INSOLACAO TOTAL, MENSAL(h)                                      0.636364
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Kendall para a Série Nome:_FLORIANO_Codigo_Estacao:_82678:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.787879
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.757576
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.787879
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                    0.848485
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.757576
# INSOLACAO TOTAL, MENSAL(h)                                      0.848485
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Kendall para a Série Nome:_PARNAIBA_Codigo_Estacao:_82287:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.757576
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.515152
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.757576
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                    0.333333
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.515152
# INSOLACAO TOTAL, MENSAL(h)                                      0.333333
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Kendall para a Série Nome:_TERESINA_Codigo_Estacao:_82578:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.787879
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.575758
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.787879
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                    0.484848
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.575758
# INSOLACAO TOTAL, MENSAL(h)                                      0.484848
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Kendall para a Série Nome:_NATAL_Codigo_Estacao:_82598:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.878788
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.606061
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.878788
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                    0.606061
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.606061
# INSOLACAO TOTAL, MENSAL(h)                                      0.606061
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Kendall para a Série Nome:_ARACAJU_Codigo_Estacao:_83096:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.818182
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.878788
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.818182
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                    0.818182
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.878788
# INSOLACAO TOTAL, MENSAL(h)                                      0.818182
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000

# %%
# Exemplo de como acessar uma das matrizes de correlação de kendall resultante

kendall_results['Nome:_ITABAIANINHA_Codigo_Estacao:_83195']
# Out:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                 0.424242
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.393939
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                         0.424242
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.666667
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.393939
# INSOLACAO TOTAL, MENSAL(h)                                     -0.666667
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000

# %% [markdown]
# ## Correlação de Spearman

# %%
# Dicionário para armazenar os coeficientes de Pearson
spearman_results = {}

# Loop para iterar sobre cada DataFrame no dicionário
for nome_serie, serie in ano_caracteristico.items():
    # Calculando o coeficiente de Pearson entre cada par de colunas
    spearman_matrix = serie.corr(method='spearman')

    # Armazenar os resultados no dicionário
    spearman_results[nome_serie] = spearman_matrix

# %%
# Exibir os resultados
for nome_serie, spearman_matrix in spearman_results.items():
    print(f"Coeficientes de Spearman para o DataFrame {nome_serie}:")
    print(spearman_matrix)
    print()
# Out:
# Coeficientes de Spearman para o DataFrame Nome:_AGUA_BRANCA_Codigo_Estacao:_82989:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                 0.804196
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.713287
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                         0.804196
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.937063
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.713287
# INSOLACAO TOTAL, MENSAL(h)                                     -0.937063
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Spearman para o DataFrame Nome:_ARAPIRACA_Codigo_Estacao:_82995:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                                  NaN
# INSOLACAO TOTAL, MENSAL(h)                                      NaN
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             NaN
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                              NaN
# INSOLACAO TOTAL, MENSAL(h)                                  NaN
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                         NaN
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                       NaN
# INSOLACAO TOTAL, MENSAL(h)                                           NaN
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                                  NaN
#
# Coeficientes de Spearman para o DataFrame Nome:_MACEIO_Codigo_Estacao:_82994:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                 0.570929
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.805263
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                         0.570929
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.647987
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.805263
# INSOLACAO TOTAL, MENSAL(h)                                     -0.647987
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Spearman para o DataFrame Nome:_MAJOR_ISIDORO_Codigo_Estacao:_82991:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                                  NaN
# INSOLACAO TOTAL, MENSAL(h)                                      NaN
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             NaN
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                              NaN
# INSOLACAO TOTAL, MENSAL(h)                                  NaN
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                         NaN
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                       NaN
# INSOLACAO TOTAL, MENSAL(h)                                           NaN
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                                  NaN
#
# Coeficientes de Spearman para o DataFrame Nome:_MATA_GRANDE_Codigo_Estacao:_82988:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                                  NaN
# INSOLACAO TOTAL, MENSAL(h)                                      NaN
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             NaN
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                              NaN
# INSOLACAO TOTAL, MENSAL(h)                                  NaN
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                         NaN
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                       NaN
# INSOLACAO TOTAL, MENSAL(h)                                           NaN
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                                  NaN
#
# Coeficientes de Spearman para o DataFrame Nome:_PALMEIRA_DOS_INDIOS_Codigo_Estacao:_82992:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                 0.671329
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.342657
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                         0.671329
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.741259
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.342657
# INSOLACAO TOTAL, MENSAL(h)                                     -0.741259
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Spearman para o DataFrame Nome:_PAO_DE_ACUCAR_Codigo_Estacao:_82990:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                 0.629371
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.783217
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                         0.629371
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.937063
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.783217
# INSOLACAO TOTAL, MENSAL(h)                                     -0.937063
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Spearman para o DataFrame Nome:_PILAR_(MANGUABA)_Codigo_Estacao:_82998:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                                  NaN
# INSOLACAO TOTAL, MENSAL(h)                                      NaN
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             NaN
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                              NaN
# INSOLACAO TOTAL, MENSAL(h)                                  NaN
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                         NaN
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                       NaN
# INSOLACAO TOTAL, MENSAL(h)                                           NaN
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                                  NaN
#
# Coeficientes de Spearman para o DataFrame Nome:_PORTO_DE_PEDRAS_Codigo_Estacao:_82996:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                 0.328671
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.748252
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                         0.328671
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.671329
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.748252
# INSOLACAO TOTAL, MENSAL(h)                                     -0.671329
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Spearman para o DataFrame Nome:_ALAGOINHAS_Codigo_Estacao:_83249:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                 0.685315
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.412587
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                         0.685315
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.104895
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.412587
# INSOLACAO TOTAL, MENSAL(h)                                     -0.104895
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Spearman para o DataFrame Nome:_BARRA_Codigo_Estacao:_83179:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.811189
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.006993
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.811189
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                    0.000000
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.006993
# INSOLACAO TOTAL, MENSAL(h)                                      0.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Spearman para o DataFrame Nome:_CAETITE_Codigo_Estacao:_83339:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.860140
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                        0.328671
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.860140
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.671329
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                  0.328671
# INSOLACAO TOTAL, MENSAL(h)                                     -0.671329
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Spearman para o DataFrame Nome:_CAMACARI_Codigo_Estacao:_83226:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                 0.699301
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.727273
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                         0.699301
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.916084
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.727273
# INSOLACAO TOTAL, MENSAL(h)                                     -0.916084
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Spearman para o DataFrame Nome:_CANAVIEIRAS_Codigo_Estacao:_83398:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                 0.587413
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.188811
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                         0.587413
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.041958
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.188811
# INSOLACAO TOTAL, MENSAL(h)                                     -0.041958
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Spearman para o DataFrame Nome:_CARINHANHA_Codigo_Estacao:_83408:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.958042
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                        0.062937
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.958042
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.167832
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                  0.062937
# INSOLACAO TOTAL, MENSAL(h)                                     -0.167832
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Spearman para o DataFrame Nome:_CIPO_Codigo_Estacao:_83192:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                 0.489510
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.566434
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                          0.48951
# INSOLACAO TOTAL, MENSAL(h)                              1.00000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                     0.00000
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.566434
# INSOLACAO TOTAL, MENSAL(h)                                      0.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Spearman para o DataFrame Nome:_CORRENTINA_Codigo_Estacao:_83286:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.930070
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                        0.388792
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                         -0.93007
# INSOLACAO TOTAL, MENSAL(h)                              1.00000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                    -0.06655
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                  0.388792
# INSOLACAO TOTAL, MENSAL(h)                                     -0.066550
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Spearman para o DataFrame Nome:_CRUZ_DAS_ALMAS_Codigo_Estacao:_83222:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                 0.650350
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.853147
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                         0.650350
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.706294
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.853147
# INSOLACAO TOTAL, MENSAL(h)                                     -0.706294
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Spearman para o DataFrame Nome:_FEIRA_DE_SANTANA_Codigo_Estacao:_83221:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                 0.832168
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.587413
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                         0.832168
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.713287
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.587413
# INSOLACAO TOTAL, MENSAL(h)                                     -0.713287
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Spearman para o DataFrame Nome:_GUARATINGA_Codigo_Estacao:_83446:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.636364
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.297724
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.636364
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.161121
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.297724
# INSOLACAO TOTAL, MENSAL(h)                                     -0.161121
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Spearman para o DataFrame Nome:_IRECE_Codigo_Estacao:_83182:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.832168
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                        0.020979
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.832168
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                    0.419580
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                  0.020979
# INSOLACAO TOTAL, MENSAL(h)                                      0.419580
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Spearman para o DataFrame Nome:_ITABERABA_Codigo_Estacao:_83244:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                 0.377622
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.321678
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                         0.377622
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.244755
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.321678
# INSOLACAO TOTAL, MENSAL(h)                                     -0.244755
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Spearman para o DataFrame Nome:_ITABUNA_Codigo_Estacao:_83347:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                                  NaN
# INSOLACAO TOTAL, MENSAL(h)                                      NaN
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             NaN
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                              NaN
# INSOLACAO TOTAL, MENSAL(h)                                  NaN
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                         NaN
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                       NaN
# INSOLACAO TOTAL, MENSAL(h)                                           NaN
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                                  NaN
#
# Coeficientes de Spearman para o DataFrame Nome:_ITIRUCU_(JAGUAQUARA)_Codigo_Estacao:_83295:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                 0.118881
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.867133
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                         0.118881
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.349650
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.867133
# INSOLACAO TOTAL, MENSAL(h)                                     -0.349650
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Spearman para o DataFrame Nome:_ITUACU_Codigo_Estacao:_83292:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.654992
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                        0.916084
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.654992
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.542908
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                  0.916084
# INSOLACAO TOTAL, MENSAL(h)                                     -0.542908
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Spearman para o DataFrame Nome:_MONTE_SANTO_Codigo_Estacao:_83090:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                 0.598950
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.769231
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                         0.598950
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.886166
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.769231
# INSOLACAO TOTAL, MENSAL(h)                                     -0.886166
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Spearman para o DataFrame Nome:_MORRO_DO_CHAPEU_Codigo_Estacao:_83184:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                 0.447552
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.650350
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                         0.447552
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.895105
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.650350
# INSOLACAO TOTAL, MENSAL(h)                                     -0.895105
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Spearman para o DataFrame Nome:_MUCURI_Codigo_Estacao:_83549:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                                  NaN
# INSOLACAO TOTAL, MENSAL(h)                                      NaN
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             NaN
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                              NaN
# INSOLACAO TOTAL, MENSAL(h)                                  NaN
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                         NaN
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                       NaN
# INSOLACAO TOTAL, MENSAL(h)                                           NaN
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                                  NaN
#
# Coeficientes de Spearman para o DataFrame Nome:_PAULO_AFONSO_Codigo_Estacao:_82986:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                 0.629371
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.790210
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                         0.629371
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.804196
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.790210
# INSOLACAO TOTAL, MENSAL(h)                                     -0.804196
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Spearman para o DataFrame Nome:_REMANSO_Codigo_Estacao:_82979:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.755245
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                        0.594406
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.755245
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.377622
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                  0.594406
# INSOLACAO TOTAL, MENSAL(h)                                     -0.377622
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Spearman para o DataFrame Nome:_SENHOR_DO_BONFIM_Codigo_Estacao:_83088:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                 0.678322
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.853147
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                         0.678322
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.860140
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.853147
# INSOLACAO TOTAL, MENSAL(h)                                     -0.860140
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Spearman para o DataFrame Nome:_SERRINHA_Codigo_Estacao:_83190:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                 0.608392
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.783217
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                         0.608392
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.867133
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.783217
# INSOLACAO TOTAL, MENSAL(h)                                     -0.867133
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Spearman para o DataFrame Nome:_STa._R._DE_CASSIA_(IBIPETUBA)_Codigo_Estacao:_83076:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.783217
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.069930
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.783217
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.335664
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.069930
# INSOLACAO TOTAL, MENSAL(h)                                     -0.335664
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Spearman para o DataFrame Nome:_ACARAU_Codigo_Estacao:_82294:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.664336
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                        0.048951
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.664336
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.034965
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                  0.048951
# INSOLACAO TOTAL, MENSAL(h)                                     -0.034965
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Spearman para o DataFrame Nome:_CAMPOS_SALES_Codigo_Estacao:_82777:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.713287
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.272727
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.713287
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                    0.699301
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.272727
# INSOLACAO TOTAL, MENSAL(h)                                      0.699301
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Spearman para o DataFrame Nome:_GUARAMIRANGA_Codigo_Estacao:_82487:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.412587
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.167832
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.412587
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.727273
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.167832
# INSOLACAO TOTAL, MENSAL(h)                                     -0.727273
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Spearman para o DataFrame Nome:_IGUATU_Codigo_Estacao:_82686:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.419580
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                        0.083916
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.419580
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                    0.286713
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                  0.083916
# INSOLACAO TOTAL, MENSAL(h)                                      0.286713
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Spearman para o DataFrame Nome:_JAGUARUANA_Codigo_Estacao:_82493:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.552448
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.041958
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.552448
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.454545
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.041958
# INSOLACAO TOTAL, MENSAL(h)                                     -0.454545
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Spearman para o DataFrame Nome:_JUAZEIRO_DO_NORTE_Codigo_Estacao:_82785:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                                  NaN
# INSOLACAO TOTAL, MENSAL(h)                                      NaN
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             NaN
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                              NaN
# INSOLACAO TOTAL, MENSAL(h)                                  NaN
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                         NaN
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                       NaN
# INSOLACAO TOTAL, MENSAL(h)                                           NaN
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                                  NaN
#
# Coeficientes de Spearman para o DataFrame Nome:_MORADA_NOVA_Codigo_Estacao:_82588:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                              1.00000
# INSOLACAO TOTAL, MENSAL(h)                                 -0.48951
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                         0.13986
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.489510
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.643357
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                  0.139860
# INSOLACAO TOTAL, MENSAL(h)                                     -0.643357
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Spearman para o DataFrame Nome:_QUIXADA_Codigo_Estacao:_82486:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                                  NaN
# INSOLACAO TOTAL, MENSAL(h)                                      NaN
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             NaN
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                              NaN
# INSOLACAO TOTAL, MENSAL(h)                                  NaN
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                         NaN
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                       NaN
# INSOLACAO TOTAL, MENSAL(h)                                           NaN
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                                  NaN
#
# Coeficientes de Spearman para o DataFrame Nome:_SOBRAL_Codigo_Estacao:_82392:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.363636
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.377622
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.363636
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.202797
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.377622
# INSOLACAO TOTAL, MENSAL(h)                                     -0.202797
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Spearman para o DataFrame Nome:_TAUA_Codigo_Estacao:_82683:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.510490
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                        0.713287
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.510490
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.531469
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                  0.713287
# INSOLACAO TOTAL, MENSAL(h)                                     -0.531469
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Spearman para o DataFrame Nome:_VICOSA_DO_CEARA_Codigo_Estacao:_82390:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                                  NaN
# INSOLACAO TOTAL, MENSAL(h)                                      NaN
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             NaN
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                              NaN
# INSOLACAO TOTAL, MENSAL(h)                                  NaN
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                         NaN
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                       NaN
# INSOLACAO TOTAL, MENSAL(h)                                           NaN
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                                  NaN
#
# Coeficientes de Spearman para o DataFrame Nome:_ALTO_PARNAIBA_Codigo_Estacao:_82970:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.797203
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                        0.776224
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.797203
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.867133
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                  0.776224
# INSOLACAO TOTAL, MENSAL(h)                                     -0.867133
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Spearman para o DataFrame Nome:_BALSAS_Codigo_Estacao:_82768:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.720280
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                        0.034965
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.720280
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.076923
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                  0.034965
# INSOLACAO TOTAL, MENSAL(h)                                     -0.076923
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Spearman para o DataFrame Nome:_CAXIAS_Codigo_Estacao:_82476:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.524476
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                        0.041958
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.524476
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                    0.503497
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                  0.041958
# INSOLACAO TOTAL, MENSAL(h)                                      0.503497
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Spearman para o DataFrame Nome:_CHAPADINHA_Codigo_Estacao:_82382:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.272727
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.146853
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.272727
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.741259
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.146853
# INSOLACAO TOTAL, MENSAL(h)                                     -0.741259
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Spearman para o DataFrame Nome:_COLINAS_Codigo_Estacao:_82676:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.580420
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                        0.769231
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.580420
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.405594
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                  0.769231
# INSOLACAO TOTAL, MENSAL(h)                                     -0.405594
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Spearman para o DataFrame Nome:_IMPERATRIZ_Codigo_Estacao:_82564:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.699301
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                        0.804196
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.699301
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.825175
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                  0.804196
# INSOLACAO TOTAL, MENSAL(h)                                     -0.825175
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Spearman para o DataFrame Nome:_TURIACU_Codigo_Estacao:_82198:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.307692
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                        0.230769
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.307692
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                    0.426573
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                  0.230769
# INSOLACAO TOTAL, MENSAL(h)                                      0.426573
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Spearman para o DataFrame Nome:_ZE_DOCA_Codigo_Estacao:_82376:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# ...
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Spearman para o DataFrame Nome:_VITORIA_DA_CONQUISTA_Codigo_Estacao:_83344:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.069930
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.356643
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.069930
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                    0.363636
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.356643
# INSOLACAO TOTAL, MENSAL(h)                                      0.363636
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Spearman para o DataFrame Nome:_BARBALHA_Codigo_Estacao:_82784:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.860140
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.965035
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.860140
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                    0.776224
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.965035
# INSOLACAO TOTAL, MENSAL(h)                                      0.776224
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Spearman para o DataFrame Nome:_CRATEUS_Codigo_Estacao:_82583:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.909091
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.944056
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.909091
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                    0.909091
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.944056
# INSOLACAO TOTAL, MENSAL(h)                                      0.909091
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Spearman para o DataFrame Nome:_FORTALEZA_Codigo_Estacao:_82397:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.965035
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.986014
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.965035
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                    0.965035
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.986014
# INSOLACAO TOTAL, MENSAL(h)                                      0.965035
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Spearman para o DataFrame Nome:_QUIXERAMOBIM_Codigo_Estacao:_82586:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.937063
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.776224
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.937063
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                    0.664336
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.776224
# INSOLACAO TOTAL, MENSAL(h)                                      0.664336
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Spearman para o DataFrame Nome:_BACABAL_Codigo_Estacao:_82460:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.902098
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.804196
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.902098
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                    0.580420
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.804196
# INSOLACAO TOTAL, MENSAL(h)                                      0.580420
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Spearman para o DataFrame Nome:_BARRA_DO_CORDA_Codigo_Estacao:_82571:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.965035
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.942208
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.965035
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                    0.858145
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.942208
# INSOLACAO TOTAL, MENSAL(h)                                      0.858145
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Spearman para o DataFrame Nome:_CAROLINA_Codigo_Estacao:_82765:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.923077
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.734266
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.923077
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                    0.699301
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.734266
# INSOLACAO TOTAL, MENSAL(h)                                      0.699301
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Spearman para o DataFrame Nome:_SAO_LUIS_Codigo_Estacao:_82280:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.937063
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.832168
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.937063
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                    0.734266
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.832168
# INSOLACAO TOTAL, MENSAL(h)                                      0.734266
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Spearman para o DataFrame Nome:_PATOS_Codigo_Estacao:_82791:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.601399
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.888112
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.601399
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                    0.748252
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.888112
# INSOLACAO TOTAL, MENSAL(h)                                      0.748252
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Spearman para o DataFrame Nome:_PETROLINA_Codigo_Estacao:_82983:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.475524
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.944056
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.475524
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                    0.629371
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.944056
# INSOLACAO TOTAL, MENSAL(h)                                      0.629371
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Spearman para o DataFrame Nome:_RECIFE_(CURADO)_Codigo_Estacao:_82900:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.916084
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.937063
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.916084
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                    0.797203
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.937063
# INSOLACAO TOTAL, MENSAL(h)                                      0.797203
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Spearman para o DataFrame Nome:_FLORIANO_Codigo_Estacao:_82678:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.923077
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.916084
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.923077
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                    0.951049
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.916084
# INSOLACAO TOTAL, MENSAL(h)                                      0.951049
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Spearman para o DataFrame Nome:_PARNAIBA_Codigo_Estacao:_82287:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.909091
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.692308
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.909091
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                    0.538462
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.692308
# INSOLACAO TOTAL, MENSAL(h)                                      0.538462
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Spearman para o DataFrame Nome:_TERESINA_Codigo_Estacao:_82578:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.916084
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.755245
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.916084
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                    0.727273
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.755245
# INSOLACAO TOTAL, MENSAL(h)                                      0.727273
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Spearman para o DataFrame Nome:_NATAL_Codigo_Estacao:_82598:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.951049
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.790210
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.951049
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                    0.804196
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.790210
# INSOLACAO TOTAL, MENSAL(h)                                      0.804196
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000
#
# Coeficientes de Spearman para o DataFrame Nome:_ARACAJU_Codigo_Estacao:_83096:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                -0.944056
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.972028
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                        -0.944056
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                    0.944056
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.972028
# INSOLACAO TOTAL, MENSAL(h)                                      0.944056
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000

# %%
# Exemplo de como acessar uma das matrizes de correlação de kendall resultante

spearman_results['Nome:_ITABAIANINHA_Codigo_Estacao:_83195']
# Out:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                 0.615385
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.587413
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                         0.615385
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.825175
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.587413
# INSOLACAO TOTAL, MENSAL(h)                                     -0.825175
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000

# %% [markdown]
# # TESTE MAPAS DE CALOR

# %%
# bibliotecas necessárias
import geopandas as gpd
import folium
from folium.plugins import HeatMap

# %%
#ler as 9 primeiras linhas
# 'Nome:_AGUA_BRANCA_Codigo_Estacao:_82989'

caminho_arquivo = '/content/drive/MyDrive/TCC/DADOS/CONVENCIONAL/Nome:_AGUA_BRANCA_Codigo_Estacao:_82989.csv'
dic_teste = {}

with open(caminho_arquivo, 'r') as file:
        # Ler as 9 primeiras linhas do arquivo
        for _ in range(9):
            linha = next(file).strip()
            if ':' in linha:
                chave, valor = linha.split(':', 1)  # Dividir na primeira ocorrência de ':'
                dic_teste[chave.strip()] = valor.strip()
            else:
                dic_teste[f"linha_{_+1}"] = linha.strip()

# %%
dic_teste
# Out:
# {'Nome': 'AGUA BRANCA',
#  'Codigo Estacao': '82989',
#  'Latitude': '-9.26472222',
#  'Longitude': '-37.93805555',
#  'Altitude': '603.42',
#  'Situacao': 'Operante',
#  'Data Inicial': '2000-01-01',
#  'Data Final': '2024-06-01',
#  'Periodicidade da Medicao': 'Mensal'}

# %%
# transformar o dicionário em df
df_teste = pd.DataFrame(dic_teste, index=[0])

# %%
df_teste
# Out:
#           Nome Codigo Estacao     Latitude     Longitude Altitude  Situacao  \
# 0  AGUA BRANCA          82989  -9.26472222  -37.93805555   603.42  Operante
#
#   Data Inicial  Data Final Periodicidade da Medicao
# 0   2000-01-01  2024-06-01                   Mensal

# %%
# construção do ponto geométrico
geometry = [Point(xy) for xy in zip(df_teste['Longitude'], df_teste['Latitude'])]

#inserir o ponto geométrico como uma nova coluna
df_teste['geometry'] = geometry

#mostrar o df_teste
df_teste
# Out:
#           Nome Codigo Estacao     Latitude     Longitude Altitude  Situacao  \
# 0  AGUA BRANCA          82989  -9.26472222  -37.93805555   603.42  Operante
#
#   Data Inicial  Data Final Periodicidade da Medicao  \
# 0   2000-01-01  2024-06-01                   Mensal
#
#                            geometry
# 0  POINT (-37.93805555 -9.26472222)

# %%
# matriz de person para agua branca
P_AGUA_BRANCA = pearson_results['Nome:_AGUA_BRANCA_Codigo_Estacao:_82989']
P_AGUA_BRANCA
# Out:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                 0.789641
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.771172
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                         0.789641
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.952617
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.771172
# INSOLACAO TOTAL, MENSAL(h)                                     -0.952617
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000

# %%
prec = 'PRECIPITACAO TOTAL, MENSAL(mm)'
vento = 'VENTO, VELOCIDADE MEDIA MENSAL(m/s)'
insol = 'INSOLACAO TOTAL, MENSAL(h)'

# Pegar as correlações específicas de Person e jogar em variáveis
P1 = P_AGUA_BRANCA.loc[insol, prec]
P2 = P_AGUA_BRANCA.loc[vento, prec]
P3 = P_AGUA_BRANCA.loc[vento, insol]
print('P1: C. Person para precipitação vs insolação:',P1)
print('P2: C. Person para precipitação vs v. vento:',P2)
print('P3: C. Person para insolação vs v. vento:',P3)
# Out:
# P1: C. Person para precipitação vs insolação: 0.7896410000314961
# P2: C. Person para precipitação vs v. vento: -0.7711723440877374
# P3: C. Person para insolação vs v. vento: -0.9526168499001665

# %%
K_AGUA_BRANCA = kendall_results['Nome:_AGUA_BRANCA_Codigo_Estacao:_82989']
K_AGUA_BRANCA
# Out:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                 0.606061
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.515152
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                         0.606061
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.848485
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.515152
# INSOLACAO TOTAL, MENSAL(h)                                     -0.848485
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000

# %%
prec = 'PRECIPITACAO TOTAL, MENSAL(mm)'
vento = 'VENTO, VELOCIDADE MEDIA MENSAL(m/s)'
insol = 'INSOLACAO TOTAL, MENSAL(h)'

# Pegar as correlações específicas de Person e jogar em variáveis
K1 = K_AGUA_BRANCA.loc[insol, prec]
K2 = K_AGUA_BRANCA.loc[vento, prec]
K3 = K_AGUA_BRANCA.loc[vento, insol]
print('K1: C. KENDALL para precipitação vs insolação:',K1)
print('K2: C. KENDALL para precipitação vs v. vento:',K2)
print('K3: C. KENDALL para insolação vs v. vento:',K3)
# Out:
# K1: C. KENDALL para precipitação vs insolação: 0.606060606060606
# K2: C. KENDALL para precipitação vs v. vento: -0.5151515151515151
# K3: C. KENDALL para insolação vs v. vento: -0.8484848484848484

# %%
S_AGUA_BRANCA = spearman_results['Nome:_AGUA_BRANCA_Codigo_Estacao:_82989']
S_AGUA_BRANCA
# Out:
#                                      PRECIPITACAO TOTAL, MENSAL(mm)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                             1.000000
# INSOLACAO TOTAL, MENSAL(h)                                 0.804196
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                       -0.713287
#
#                                      INSOLACAO TOTAL, MENSAL(h)  \
# PRECIPITACAO TOTAL, MENSAL(mm)                         0.804196
# INSOLACAO TOTAL, MENSAL(h)                             1.000000
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                   -0.937063
#
#                                      VENTO, VELOCIDADE MEDIA MENSAL(m/s)
# PRECIPITACAO TOTAL, MENSAL(mm)                                 -0.713287
# INSOLACAO TOTAL, MENSAL(h)                                     -0.937063
# VENTO, VELOCIDADE MEDIA MENSAL(m/s)                             1.000000

# %%
prec = 'PRECIPITACAO TOTAL, MENSAL(mm)'
vento = 'VENTO, VELOCIDADE MEDIA MENSAL(m/s)'
insol = 'INSOLACAO TOTAL, MENSAL(h)'

# Pegar as correlações específicas de Person e jogar em variáveis
S1 = S_AGUA_BRANCA.loc[insol, prec]
S2 = S_AGUA_BRANCA.loc[vento, prec]
S3 = S_AGUA_BRANCA.loc[vento, insol]
print('S1: C. SPEARMAN para precipitação vs insolação:',S1)
print('S2: C. SPEARMAN para precipitação vs v. vento:',S2)
print('S3: C. SPEARMAN para insolação vs v. vento:',S3)
# Out:
# S1: C. SPEARMAN para precipitação vs insolação: 0.8041958041958042
# S2: C. SPEARMAN para precipitação vs v. vento: -0.7132867132867133
# S3: C. SPEARMAN para insolação vs v. vento: -0.9370629370629371

# %%
# inserindo os coeficientes no DF de agua branca

df_teste['P1'] = P1
df_teste['P2'] = P2
df_teste['P3'] = P3
df_teste['K1'] = K1
df_teste['K2'] = K2
df_teste['K3'] = K3
df_teste['S1'] = S1
df_teste['S2'] = S2
df_teste['S3'] = S3

#exibindo o df de agua branca
df_teste
# Out:
#           Nome Codigo Estacao     Latitude     Longitude Altitude  Situacao  \
# 0  AGUA BRANCA          82989  -9.26472222  -37.93805555   603.42  Operante
#
#   Data Inicial  Data Final Periodicidade da Medicao  \
# 0   2000-01-01  2024-06-01                   Mensal
#
#                            geometry        P1        P2        P3        K1  \
# 0  POINT (-37.93805555 -9.26472222)  0.789641 -0.771172 -0.952617  0.606061
#
#          K2        K3        S1        S2        S3
# 0 -0.515152 -0.848485  0.804196 -0.713287 -0.937063

# %%
df_teste.dtypes
# Out:
# Nome                         object
# Codigo Estacao               object
# Latitude                     object
# Longitude                    object
# Altitude                     object
# Situacao                     object
# Data Inicial                 object
# Data Final                   object
# Periodicidade da Medicao     object
# geometry                     object
# P1                          float64
# P2                          float64
# P3                          float64
# K1                          float64
# K2                          float64
# K3                          float64
# S1                          float64
# S2                          float64
# S3                          float64
# dtype: object

# %%
# Converter a coluna 'Latitude' para float
df_teste['Latitude'] = df_teste['Latitude'].astype(float)

# Converter a coluna 'Longitude' para float
df_teste['Longitude'] = df_teste['Longitude'].astype(float)

df_teste.dtypes
# Out:
# Nome                         object
# Codigo Estacao               object
# Latitude                    float64
# Longitude                   float64
# Altitude                     object
# Situacao                     object
# Data Inicial                 object
# Data Final                   object
# Periodicidade da Medicao     object
# geometry                     object
# P1                          float64
# P2                          float64
# P3                          float64
# K1                          float64
# K2                          float64
# K3                          float64
# S1                          float64
# S2                          float64
# S3                          float64
# dtype: object

# %%
# Selecionar 3 colunas específicas e converter em uma lista
colunas_especificas = ['Latitude', 'Longitude', 'P1']
lista_teste = df_teste[colunas_especificas].values.tolist()[0]

lista_teste
# Out:
# [-9.26472222, -37.93805555, 0.7896410000314961]

# %%
import folium
from folium.plugins import HeatMap

data = df_teste[['Latitude', 'Longitude', 'P1']].values.tolist()

# Criar um mapa base centrado nas coordenadas médias
m = folium.Map

# Adicionar o HeatMap ao mapa
HeatMap(data).add_to(m)

# Salvar o mapa como um arquivo HTML
m.save('mapa_calor.html')

m
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-93-c684646ca730> in <cell line: 10>()
#       8
#       9 # Adicionar o HeatMap ao mapa
# ---> 10 HeatMap(data).add_to(m)
#      11
#      12 # Salvar o mapa como um arquivo HTML
#
# /usr/local/lib/python3.10/dist-packages/branca/element.py in add_to(self, parent, name, index)
#     142     def add_to(self, parent, name=None, index=None):
#     143         """Add element to a parent."""
# --> 144         parent.add_child(self, name=name, index=index)
#     145         return self
#     146
#
# TypeError: Element.add_child() missing 1 required positional argument: 'child'

# %%
import folium
from folium.plugins import HeatMap

data = [
    [37.7749, -122.4194, 5],  # São Francisco com peso 5
    [34.0522, -118.2437, 2],  # Los Angeles com peso 2
    [40.7128, -74.0060, 10],  # Nova York com peso 10
    [41.8781, -87.6298, 1],   # Chicago com peso 1
    [29.7604, -95.3698, 7],   # Houston com peso 7
]

# Criar um mapa base centrado nas coordenadas médias
m = folium.Map(location=[37.7749, -122.4194], zoom_start=5)

# Adicionar o HeatMap ao mapa
HeatMap(data).add_to(m)

# Salvar o mapa como um arquivo HTML
m.save('mapa_calor.html')

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bc49d43fea42596a0319591bbe8b349d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bc49d43fea42596a0319591bbe8b349d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bc49d43fea42596a0319591bbe8b349d = L.map(
#                 &quot;map_bc49d43fea42596a0319591bbe8b349d&quot;,
#                 {
#                     center: [37.7749, -122.4194],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c4b7b32f8ee83d4afbc8b9412c1cdf20 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c4b7b32f8ee83d4afbc8b9412c1cdf20.addTo(map_bc49d43fea42596a0319591bbe8b349d);
#
#
#             var heat_map_7ef2be9a66b3fc0fb61fd43760acf165 = L.heatLayer(
#                 [[37.7749, -122.4194, 5], [34.0522, -118.2437, 2], [40.7128, -74.006, 10], [41.8781, -87.6298, 1], [29.7604, -95.3698, 7]],
#                 {&quot;blur&quot;: 15, &quot;maxZoom&quot;: 18, &quot;minOpacity&quot;: 0.5, &quot;radius&quot;: 25}
#             );
#
#
#             heat_map_7ef2be9a66b3fc0fb61fd43760acf165.addTo(map_bc49d43fea42596a0319591bbe8b349d);
#
#
#             tile_layer_c4b7b32f8ee83d4afbc8b9412c1cdf20.addTo(map_bc49d43fea42596a0319591bbe8b349d);
#
#
#             heat_map_7ef2be9a66b3fc0fb61fd43760acf165.addTo(map_bc49d43fea42596a0319591bbe8b349d);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
